# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
df=pd.read_csv("Naive-Bayes-Classification-Data.csv")
x, y = df.iloc[:, :-1], df.iloc[:, -1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
df.size
# Out:
# 2985

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
dtc.score(x_test, y_test)
# Out:
# 0.9397590361445783

# %%
fig = plt.figure(figsize=(30,40))
tree.plot_tree(dtc,filled = True)
# Out:
# [Text(670.6462499999999, 2065.6800000000003, 'X[1] <= 79.0\ngini = 0.5\nsamples = 746\nvalue = [383, 363]'),
#  Text(359.90999999999997, 1848.2400000000002, 'X[1] <= 76.0\ngini = 0.101\nsamples = 338\nvalue = [18, 320]'),
#  Text(184.14, 1630.8000000000002, 'X[1] <= 72.5\ngini = 0.029\nsamples = 274\nvalue = [4, 270]'),
#  Text(150.66, 1413.3600000000001, 'gini = 0.0\nsamples = 192\nvalue = [0, 192]'),
#  Text(217.61999999999998, 1413.3600000000001, 'X[0] <= 37.5\ngini = 0.093\nsamples = 82\nvalue = [4, 78]'),
#  Text(184.14, 1195.92, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(251.09999999999997, 1195.92, 'X[0] <= 52.5\ngini = 0.112\nsamples = 67\nvalue = [4, 63]'),
#  Text(217.61999999999998, 978.48, 'X[0] <= 47.5\ngini = 0.131\nsamples = 57\nvalue = [4, 53]'),
#  Text(133.92, 761.0400000000002, 'X[1] <= 74.0\ngini = 0.122\nsamples = 46\nvalue = [3, 43]'),
#  Text(66.96, 543.6000000000001, 'X[0] <= 42.5\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(33.48, 326.1600000000001, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(100.44, 326.1600000000001, 'gini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(200.88, 543.6000000000001, 'X[0] <= 42.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(167.39999999999998, 326.1600000000001, 'gini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(234.35999999999999, 326.1600000000001, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(301.32, 761.0400000000002, 'X[1] <= 74.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(267.84, 543.6000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(334.79999999999995, 543.6000000000001, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(284.58, 978.48, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(535.68, 1630.8000000000002, 'X[0] <= 37.5\ngini = 0.342\nsamples = 64\nvalue = [14, 50]'),
#  Text(502.19999999999993, 1413.3600000000001, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(569.16, 1413.3600000000001, 'X[0] <= 52.5\ngini = 0.423\nsamples = 46\nvalue = [14, 32]'),
#  Text(535.68, 1195.92, 'X[1] <= 77.5\ngini = 0.444\nsamples = 42\nvalue = [14, 28]'),
#  Text(468.71999999999997, 978.48, 'X[0] <= 47.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(435.23999999999995, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(401.76, 543.6000000000001, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(468.71999999999997, 543.6000000000001, 'gini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(502.19999999999993, 761.0400000000002, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(602.64, 978.48, 'X[0] <= 47.5\ngini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(569.16, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(535.68, 543.6000000000001, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(602.64, 543.6000000000001, 'gini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(636.1199999999999, 761.0400000000002, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(602.64, 1195.92, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(981.3824999999999, 1848.2400000000002, 'X[0] <= 37.5\ngini = 0.189\nsamples = 408\nvalue = [365, 43]'),
#  Text(736.56, 1630.8000000000002, 'X[1] <= 89.0\ngini = 0.426\nsamples = 26\nvalue = [8, 18]'),
#  Text(703.0799999999999, 1413.3600000000001, 'X[0] <= 32.5\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(669.5999999999999, 1195.92, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(736.56, 1195.92, 'X[1] <= 81.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(703.0799999999999, 978.48, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(770.04, 978.48, 'X[1] <= 87.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(736.56, 761.0400000000002, 'X[1] <= 84.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(703.0799999999999, 543.6000000000001, 'X[1] <= 82.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(669.5999999999999, 326.1600000000001, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(736.56, 326.1600000000001, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(770.04, 543.6000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(803.52, 761.0400000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(770.04, 1413.3600000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1226.205, 1630.8000000000002, 'X[1] <= 82.5\ngini = 0.122\nsamples = 382\nvalue = [357, 25]'),
#  Text(954.18, 1413.3600000000001, 'X[0] <= 42.5\ngini = 0.383\nsamples = 62\nvalue = [46, 16]'),
#  Text(870.4799999999999, 1195.92, 'X[1] <= 81.0\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(836.9999999999999, 978.48, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(903.9599999999999, 978.48, 'gini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(1037.8799999999999, 1195.92, 'X[0] <= 47.5\ngini = 0.315\nsamples = 46\nvalue = [37, 9]'),
#  Text(970.92, 978.48, 'X[1] <= 81.0\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(937.4399999999999, 761.0400000000002, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(1004.3999999999999, 761.0400000000002, 'gini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(1104.84, 978.48, 'X[1] <= 81.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(1071.36, 761.0400000000002, 'gini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(1138.32, 761.0400000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1498.2299999999998, 1413.3600000000001, 'X[0] <= 57.5\ngini = 0.055\nsamples = 320\nvalue = [311, 9]'),
#  Text(1464.7499999999998, 1195.92, 'X[1] <= 87.5\ngini = 0.049\nsamples = 319\nvalue = [311, 8]'),
#  Text(1322.4599999999998, 978.48, 'X[0] <= 47.5\ngini = 0.094\nsamples = 142\nvalue = [135, 7]'),
#  Text(1205.28, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.085\nsamples = 113\nvalue = [108, 5]'),
#  Text(1138.32, 543.6000000000001, 'X[1] <= 86.0\ngini = 0.117\nsamples = 48\nvalue = [45, 3]'),
#  Text(1104.84, 326.1600000000001, 'X[1] <= 84.0\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(1071.36, 108.72000000000025, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(1138.32, 108.72000000000025, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(1171.8, 326.1600000000001, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(1272.2399999999998, 543.6000000000001, 'X[1] <= 84.0\ngini = 0.06\nsamples = 65\nvalue = [63, 2]'),
#  Text(1238.76, 326.1600000000001, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(1305.7199999999998, 326.1600000000001, 'X[1] <= 86.0\ngini = 0.081\nsamples = 47\nvalue = [45, 2]'),
#  Text(1272.2399999999998, 108.72000000000025, 'gini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(1339.1999999999998, 108.72000000000025, 'gini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(1439.6399999999999, 761.0400000000002, 'X[1] <= 86.0\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(1406.1599999999999, 543.6000000000001, 'X[1] <= 84.0\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(1372.6799999999998, 326.1600000000001, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(1439.6399999999999, 326.1600000000001, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(1473.12, 543.6000000000001, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1607.04, 978.48, 'X[1] <= 89.0\ngini = 0.011\nsamples = 177\nvalue = [176, 1]'),
#  Text(1573.56, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.034\nsamples = 58\nvalue = [57, 1]'),
#  Text(1540.08, 543.6000000000001, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(1607.04, 543.6000000000001, 'X[0] <= 47.5\ngini = 0.051\nsamples = 38\nvalue = [37, 1]'),
#  Text(1573.56, 326.1600000000001, 'gini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(1640.5199999999998, 326.1600000000001, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(1640.5199999999998, 761.0400000000002, 'gini = 0.0\nsamples = 119\nvalue = [119, 0]'),
#  Text(1531.7099999999998, 1195.92, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100)
clf_gini.fit(x_train, y_train)
clf_gini.score(x_test, y_test)
# Out:
# 0.9397590361445783

# %%
fig = plt.figure(figsize=(30,40))
tree.plot_tree(clf_gini,filled = True)
# Out:
# [Text(670.6462499999999, 2065.6800000000003, 'X[1] <= 79.0\ngini = 0.5\nsamples = 746\nvalue = [383, 363]'),
#  Text(359.90999999999997, 1848.2400000000002, 'X[1] <= 76.0\ngini = 0.101\nsamples = 338\nvalue = [18, 320]'),
#  Text(184.14, 1630.8000000000002, 'X[1] <= 72.5\ngini = 0.029\nsamples = 274\nvalue = [4, 270]'),
#  Text(150.66, 1413.3600000000001, 'gini = 0.0\nsamples = 192\nvalue = [0, 192]'),
#  Text(217.61999999999998, 1413.3600000000001, 'X[0] <= 37.5\ngini = 0.093\nsamples = 82\nvalue = [4, 78]'),
#  Text(184.14, 1195.92, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(251.09999999999997, 1195.92, 'X[0] <= 52.5\ngini = 0.112\nsamples = 67\nvalue = [4, 63]'),
#  Text(217.61999999999998, 978.48, 'X[0] <= 47.5\ngini = 0.131\nsamples = 57\nvalue = [4, 53]'),
#  Text(133.92, 761.0400000000002, 'X[1] <= 74.0\ngini = 0.122\nsamples = 46\nvalue = [3, 43]'),
#  Text(66.96, 543.6000000000001, 'X[0] <= 42.5\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(33.48, 326.1600000000001, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(100.44, 326.1600000000001, 'gini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(200.88, 543.6000000000001, 'X[0] <= 42.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(167.39999999999998, 326.1600000000001, 'gini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(234.35999999999999, 326.1600000000001, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(301.32, 761.0400000000002, 'X[1] <= 74.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(267.84, 543.6000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(334.79999999999995, 543.6000000000001, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(284.58, 978.48, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(535.68, 1630.8000000000002, 'X[0] <= 37.5\ngini = 0.342\nsamples = 64\nvalue = [14, 50]'),
#  Text(502.19999999999993, 1413.3600000000001, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(569.16, 1413.3600000000001, 'X[0] <= 52.5\ngini = 0.423\nsamples = 46\nvalue = [14, 32]'),
#  Text(535.68, 1195.92, 'X[1] <= 77.5\ngini = 0.444\nsamples = 42\nvalue = [14, 28]'),
#  Text(468.71999999999997, 978.48, 'X[0] <= 47.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(435.23999999999995, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(401.76, 543.6000000000001, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(468.71999999999997, 543.6000000000001, 'gini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(502.19999999999993, 761.0400000000002, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(602.64, 978.48, 'X[0] <= 47.5\ngini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(569.16, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(535.68, 543.6000000000001, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(602.64, 543.6000000000001, 'gini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(636.1199999999999, 761.0400000000002, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(602.64, 1195.92, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(981.3824999999999, 1848.2400000000002, 'X[0] <= 37.5\ngini = 0.189\nsamples = 408\nvalue = [365, 43]'),
#  Text(736.56, 1630.8000000000002, 'X[1] <= 89.0\ngini = 0.426\nsamples = 26\nvalue = [8, 18]'),
#  Text(703.0799999999999, 1413.3600000000001, 'X[1] <= 81.0\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(669.5999999999999, 1195.92, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(736.56, 1195.92, 'X[0] <= 32.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(703.0799999999999, 978.48, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(770.04, 978.48, 'X[1] <= 87.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(736.56, 761.0400000000002, 'X[1] <= 84.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(703.0799999999999, 543.6000000000001, 'X[1] <= 82.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(669.5999999999999, 326.1600000000001, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(736.56, 326.1600000000001, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(770.04, 543.6000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(803.52, 761.0400000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(770.04, 1413.3600000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1226.205, 1630.8000000000002, 'X[1] <= 82.5\ngini = 0.122\nsamples = 382\nvalue = [357, 25]'),
#  Text(954.18, 1413.3600000000001, 'X[0] <= 42.5\ngini = 0.383\nsamples = 62\nvalue = [46, 16]'),
#  Text(870.4799999999999, 1195.92, 'X[1] <= 81.0\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(836.9999999999999, 978.48, 'gini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(903.9599999999999, 978.48, 'gini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(1037.8799999999999, 1195.92, 'X[0] <= 47.5\ngini = 0.315\nsamples = 46\nvalue = [37, 9]'),
#  Text(970.92, 978.48, 'X[1] <= 81.0\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(937.4399999999999, 761.0400000000002, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(1004.3999999999999, 761.0400000000002, 'gini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(1104.84, 978.48, 'X[1] <= 81.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(1071.36, 761.0400000000002, 'gini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(1138.32, 761.0400000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1498.2299999999998, 1413.3600000000001, 'X[0] <= 57.5\ngini = 0.055\nsamples = 320\nvalue = [311, 9]'),
#  Text(1464.7499999999998, 1195.92, 'X[1] <= 87.5\ngini = 0.049\nsamples = 319\nvalue = [311, 8]'),
#  Text(1322.4599999999998, 978.48, 'X[0] <= 47.5\ngini = 0.094\nsamples = 142\nvalue = [135, 7]'),
#  Text(1205.28, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.085\nsamples = 113\nvalue = [108, 5]'),
#  Text(1138.32, 543.6000000000001, 'X[1] <= 86.0\ngini = 0.117\nsamples = 48\nvalue = [45, 3]'),
#  Text(1104.84, 326.1600000000001, 'X[1] <= 84.0\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(1071.36, 108.72000000000025, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(1138.32, 108.72000000000025, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(1171.8, 326.1600000000001, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(1272.2399999999998, 543.6000000000001, 'X[1] <= 84.0\ngini = 0.06\nsamples = 65\nvalue = [63, 2]'),
#  Text(1238.76, 326.1600000000001, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(1305.7199999999998, 326.1600000000001, 'X[1] <= 86.0\ngini = 0.081\nsamples = 47\nvalue = [45, 2]'),
#  Text(1272.2399999999998, 108.72000000000025, 'gini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(1339.1999999999998, 108.72000000000025, 'gini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(1439.6399999999999, 761.0400000000002, 'X[1] <= 86.0\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(1406.1599999999999, 543.6000000000001, 'X[1] <= 84.0\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(1372.6799999999998, 326.1600000000001, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(1439.6399999999999, 326.1600000000001, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(1473.12, 543.6000000000001, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1607.04, 978.48, 'X[1] <= 89.0\ngini = 0.011\nsamples = 177\nvalue = [176, 1]'),
#  Text(1573.56, 761.0400000000002, 'X[0] <= 42.5\ngini = 0.034\nsamples = 58\nvalue = [57, 1]'),
#  Text(1540.08, 543.6000000000001, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(1607.04, 543.6000000000001, 'X[0] <= 47.5\ngini = 0.051\nsamples = 38\nvalue = [37, 1]'),
#  Text(1573.56, 326.1600000000001, 'gini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(1640.5199999999998, 326.1600000000001, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(1640.5199999999998, 761.0400000000002, 'gini = 0.0\nsamples = 119\nvalue = [119, 0]'),
#  Text(1531.7099999999998, 1195.92, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100)
clf_entropy.fit(x_train, y_train)
clf_entropy.score(x_test, y_test)
# Out:
# 0.9397590361445783

# %%
fig = plt.figure(figsize=(30,40))
tree.plot_tree(clf_entropy,filled = True)
# Out:
# [Text(720.8777472527472, 2075.5636363636363, 'X[1] <= 79.0\nentropy = 0.999\nsamples = 746\nvalue = [383, 363]'),
#  Text(395.5054945054945, 1877.8909090909092, 'X[1] <= 76.0\nentropy = 0.3\nsamples = 338\nvalue = [18, 320]'),
#  Text(202.35164835164835, 1680.2181818181818, 'X[1] <= 72.5\nentropy = 0.11\nsamples = 274\nvalue = [4, 270]'),
#  Text(165.56043956043953, 1482.5454545454545, 'entropy = 0.0\nsamples = 192\nvalue = [0, 192]'),
#  Text(239.1428571428571, 1482.5454545454545, 'X[0] <= 37.5\nentropy = 0.281\nsamples = 82\nvalue = [4, 78]'),
#  Text(202.35164835164835, 1284.8727272727274, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(275.9340659340659, 1284.8727272727274, 'X[0] <= 52.5\nentropy = 0.326\nsamples = 67\nvalue = [4, 63]'),
#  Text(239.1428571428571, 1087.2, 'X[0] <= 47.5\nentropy = 0.367\nsamples = 57\nvalue = [4, 53]'),
#  Text(147.16483516483515, 889.5272727272727, 'X[1] <= 74.0\nentropy = 0.348\nsamples = 46\nvalue = [3, 43]'),
#  Text(73.58241758241758, 691.8545454545454, 'X[0] <= 42.5\nentropy = 0.391\nsamples = 26\nvalue = [2, 24]'),
#  Text(36.79120879120879, 494.18181818181824, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(110.37362637362637, 494.18181818181824, 'entropy = 0.485\nsamples = 19\nvalue = [2, 17]'),
#  Text(220.74725274725273, 691.8545454545454, 'X[0] <= 42.5\nentropy = 0.286\nsamples = 20\nvalue = [1, 19]'),
#  Text(183.95604395604394, 494.18181818181824, 'entropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(257.53846153846155, 494.18181818181824, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(331.12087912087907, 889.5272727272727, 'X[1] <= 74.0\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(294.3296703296703, 691.8545454545454, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(367.9120879120879, 691.8545454545454, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(312.7252747252747, 1087.2, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(588.6593406593406, 1680.2181818181818, 'X[0] <= 37.5\nentropy = 0.758\nsamples = 64\nvalue = [14, 50]'),
#  Text(551.8681318681319, 1482.5454545454545, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(625.4505494505494, 1482.5454545454545, 'X[0] <= 52.5\nentropy = 0.887\nsamples = 46\nvalue = [14, 32]'),
#  Text(588.6593406593406, 1284.8727272727274, 'X[1] <= 77.5\nentropy = 0.918\nsamples = 42\nvalue = [14, 28]'),
#  Text(515.0769230769231, 1087.2, 'X[0] <= 47.5\nentropy = 0.787\nsamples = 17\nvalue = [4, 13]'),
#  Text(478.2857142857142, 889.5272727272727, 'X[0] <= 42.5\nentropy = 0.811\nsamples = 12\nvalue = [3, 9]'),
#  Text(441.49450549450546, 691.8545454545454, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(515.0769230769231, 691.8545454545454, 'entropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(551.8681318681319, 889.5272727272727, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(662.2417582417581, 1087.2, 'X[0] <= 47.5\nentropy = 0.971\nsamples = 25\nvalue = [10, 15]'),
#  Text(625.4505494505494, 889.5272727272727, 'X[0] <= 42.5\nentropy = 0.982\nsamples = 19\nvalue = [8, 11]'),
#  Text(588.6593406593406, 691.8545454545454, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(662.2417582417581, 691.8545454545454, 'entropy = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(699.032967032967, 889.5272727272727, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(662.2417582417581, 1284.8727272727274, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1046.25, 1877.8909090909092, 'X[0] <= 37.5\nentropy = 0.486\nsamples = 408\nvalue = [365, 43]'),
#  Text(809.4065934065934, 1680.2181818181818, 'X[1] <= 89.0\nentropy = 0.89\nsamples = 26\nvalue = [8, 18]'),
#  Text(772.6153846153845, 1482.5454545454545, 'X[1] <= 81.0\nentropy = 0.755\nsamples = 23\nvalue = [5, 18]'),
#  Text(735.8241758241758, 1284.8727272727274, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(809.4065934065934, 1284.8727272727274, 'X[0] <= 32.5\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]'),
#  Text(772.6153846153845, 1087.2, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(846.1978021978022, 1087.2, 'X[1] <= 87.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(809.4065934065934, 889.5272727272727, 'X[1] <= 84.0\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(772.6153846153845, 691.8545454545454, 'X[1] <= 82.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(735.8241758241758, 494.18181818181824, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(809.4065934065934, 494.18181818181824, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(846.1978021978022, 691.8545454545454, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(882.9890109890109, 889.5272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(846.1978021978022, 1482.5454545454545, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1283.0934065934066, 1680.2181818181818, 'X[1] <= 82.5\nentropy = 0.349\nsamples = 382\nvalue = [357, 25]'),
#  Text(1048.5494505494505, 1482.5454545454545, 'X[0] <= 42.5\nentropy = 0.824\nsamples = 62\nvalue = [46, 16]'),
#  Text(956.5714285714284, 1284.8727272727274, 'X[1] <= 81.0\nentropy = 0.989\nsamples = 16\nvalue = [9, 7]'),
#  Text(919.7802197802197, 1087.2, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(993.3626373626373, 1087.2, 'entropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(1140.5274725274724, 1284.8727272727274, 'X[0] <= 47.5\nentropy = 0.713\nsamples = 46\nvalue = [37, 9]'),
#  Text(1066.9450549450548, 1087.2, 'X[1] <= 81.0\nentropy = 0.533\nsamples = 33\nvalue = [29, 4]'),
#  Text(1030.1538461538462, 889.5272727272727, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(1103.7362637362637, 889.5272727272727, 'entropy = 0.702\nsamples = 21\nvalue = [17, 4]'),
#  Text(1214.10989010989, 1087.2, 'X[1] <= 81.0\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(1177.3186813186812, 889.5272727272727, 'entropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(1250.9010989010987, 889.5272727272727, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1517.6373626373625, 1482.5454545454545, 'X[1] <= 89.0\nentropy = 0.185\nsamples = 320\nvalue = [311, 9]'),
#  Text(1480.8461538461538, 1284.8727272727274, 'X[0] <= 57.5\nentropy = 0.264\nsamples = 201\nvalue = [192, 9]'),
#  Text(1444.054945054945, 1087.2, 'X[1] <= 87.5\nentropy = 0.242\nsamples = 200\nvalue = [192, 8]'),
#  Text(1324.4835164835163, 889.5272727272727, 'X[0] <= 47.5\nentropy = 0.283\nsamples = 142\nvalue = [135, 7]'),
#  Text(1195.7142857142856, 691.8545454545454, 'X[0] <= 42.5\nentropy = 0.261\nsamples = 113\nvalue = [108, 5]'),
#  Text(1122.131868131868, 494.18181818181824, 'X[1] <= 86.0\nentropy = 0.337\nsamples = 48\nvalue = [45, 3]'),
#  Text(1085.3406593406592, 296.5090909090909, 'X[1] <= 84.0\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]'),
#  Text(1048.5494505494505, 98.83636363636379, 'entropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(1122.131868131868, 98.83636363636379, 'entropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(1158.923076923077, 296.5090909090909, 'entropy = 0.267\nsamples = 22\nvalue = [21, 1]'),
#  Text(1269.2967032967033, 494.18181818181824, 'X[1] <= 84.0\nentropy = 0.198\nsamples = 65\nvalue = [63, 2]'),
#  Text(1232.5054945054944, 296.5090909090909, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(1306.087912087912, 296.5090909090909, 'X[1] <= 86.0\nentropy = 0.254\nsamples = 47\nvalue = [45, 2]'),
#  Text(1269.2967032967033, 98.83636363636379, 'entropy = 0.229\nsamples = 27\nvalue = [26, 1]'),
#  Text(1342.8791208791208, 98.83636363636379, 'entropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(1453.2527472527472, 691.8545454545454, 'X[1] <= 86.0\nentropy = 0.362\nsamples = 29\nvalue = [27, 2]'),
#  Text(1416.4615384615383, 494.18181818181824, 'X[1] <= 84.0\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(1379.6703296703295, 296.5090909090909, 'entropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(1453.2527472527472, 296.5090909090909, 'entropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(1490.0439560439559, 494.18181818181824, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1563.6263736263736, 889.5272727272727, 'X[0] <= 42.5\nentropy = 0.126\nsamples = 58\nvalue = [57, 1]'),
#  Text(1526.8351648351647, 691.8545454545454, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(1600.4175824175823, 691.8545454545454, 'X[0] <= 47.5\nentropy = 0.176\nsamples = 38\nvalue = [37, 1]'),
#  Text(1563.6263736263736, 494.18181818181824, 'entropy = 0.222\nsamples = 28\nvalue = [27, 1]'),
#  Text(1637.2087912087911, 494.18181818181824, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(1517.6373626373625, 1087.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1554.4285714285713, 1284.8727272727274, 'entropy = 0.0\nsamples = 119\nvalue = [119, 0]')]
